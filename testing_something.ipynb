# %%
import pandas as pd

# %%
df = pd.read_csv('Reccomend_train_final.csv')

# %%
df1 = pd.read_csv('Reccomend_train160.csv')
df1[1450:1470]
# Out:
#       Unnamed: 0                                        after_merge  \
# 1450        1450  def _expand_yield_statements(macro_def, expand...
# 1451        1451      def __determine_job_destination(self, para...
# 1452        1452      def __init__(self, **kwd):\n        Binary...
# 1453        1453  def add_composite_file(dataset, registry, outp...
# 1454        1454      def tool_shed_repositories(self):\n       ...
# 1455        1455      def get_file_name(self):\n        if not s...
# 1456        1456      def get_extra_files_path(self):\n        #...
# 1457        1457      def full_delete(self):\n        """Remove ...
# 1458        1458      def get_filename(self, obj, **kwargs):\n  ...
# 1459        1459  def collect_primary_datasets(job_context, outp...
# 1460        1460      def _dataset_wrapper(self, dataset, datase...
# 1461        1461  def __main__():\n    input_name = sys.argv[1]\...
# 1462        1462      def register(self, trans, email=None, user...
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None  # default='warn'
# df[:120] = df1[:120]

# %%
for i in df.index[160:1460]:
    df['result'][i] = df1['result'][i]

# %%
for i in df.index:
    if df['result'][i] =="000_Didnt Work":
        print(i)
# Out:
# 214
# 411
# 872
# 1408

# %%
for i in df.index:
    if df['result'][i] =="000_Error":
        print(i)
# Out:
# 1872

# %%
for i in df.index:
    if df['result'][i] ==" ":
        print(i)
# Out:
# 107
# 140
# 1714

# %%
df.to_csv('Reccomend_train_final.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'after_merge',
#        'before_merge', 'source code and errors', 'full_traceback',
#        'traceback_type', 'result'],
#       dtype='object')

# %%
df.drop(columns = ['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0'], inplace = True)

# %%
df.to_csv('Reccomend_train_final.csv',index=False)

# %%
df = pd.read_csv('Reccomend_train_final.csv')

# %%
df.tail()
# Out:
#                                             after_merge  \
# 1995          def on_connect_success(result):\n     ...
# 1996      def onClose(self, wasClean, code, reason):...
# 1997      def startProxyConnect(self):\n        """\...
# 1998      def as_view(cls, actions=None, **initkwarg...
# 1999          def view(request, *args, **kwargs):\n ...
#
#                                            before_merge  \
# 1995          def on_connect_success(result):\n     ...
# 1996      def onClose(self, wasClean, code, reason):...
# 1997      def startProxyConnect(self):\n        """\...
# 1998      def as_view(cls, actions=None, **initkwarg...
# 1999          def view(request, *args, **kwargs):\n ...
#
#                                  source code and errors  \
# 1995  [{'piece_type': 'other', 'piece_content': '201...
# 1996  [{'piece_type': 'other', 'piece_content': '201...
# 1997  [{'piece_type': 'error message', 'piece_conten...
# 1998  [{'piece_type': 'other', 'piece_content': "pip...
# ...
